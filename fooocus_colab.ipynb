# %% [markdown]
# <a href="https://colab.research.google.com/github/thesuperfly21-beep/archer-t2u-plus-linux/blob/main/fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install "numpy<2.0" "cupy-cuda12x<14.0" --force-reinstall
# Out:
# ...
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
#   Using cached cupy_cuda12x-13.6.0-cp312-cp312-manylinux2014_x86_64.whl.metadata (2.4 kB)
# ...
#   Using cached fastrlock-0.8.3-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_28_x86_64.whl.metadata (7.7 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# Using cached cupy_cuda12x-13.6.0-cp312-cp312-manylinux2014_x86_64.whl (112.9 MB)
# Using cached fastrlock-0.8.3-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_28_x86_64.whl (53 kB)
# ...
#   Attempting uninstall: fastrlock
#     Found existing installation: fastrlock 0.8.3
#     Uninstalling fastrlock-0.8.3:
#       Successfully uninstalled fastrlock-0.8.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: cupy-cuda12x
# ...

# %%
# !wget --content-disposition "https://civitai.com/api/download/models/243570?type=Model&format=SafeTensor"
# Out:
# --2026-04-12 05:45:44--  https://civitai.com/api/download/models/243570?type=Model&format=SafeTensor
# Resolving civitai.com (civitai.com)... 172.66.152.186, 104.20.38.219, 2606:4700:10::6814:26db, ...
# Connecting to civitai.com (civitai.com)|172.66.152.186|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://b2.civitai.com/file/civitai-modelfiles/model/14770/nudexl.iqUR.safetensors?Authorization=3_20260412054544_855e0311cd452c3f61bf19d6_d3932240c5e150b1d9724a5da6a9d05bbf594ed7_004_20260412064544_0035_dnld&b2ContentDisposition=attachment%3B+filename%3D%22NudeXL.safetensors%22 [following]
# --2026-04-12 05:45:44--  https://b2.civitai.com/file/civitai-modelfiles/model/14770/nudexl.iqUR.safetensors?Authorization=3_20260412054544_855e0311cd452c3f61bf19d6_d3932240c5e150b1d9724a5da6a9d05bbf594ed7_004_20260412064544_0035_dnld&b2ContentDisposition=attachment%3B+filename%3D%22NudeXL.safetensors%22
# ...

# %%
# !wget --content-disposition "https://civitai.com/api/download/models/177674?type=Model&format=SafeTensor"

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
