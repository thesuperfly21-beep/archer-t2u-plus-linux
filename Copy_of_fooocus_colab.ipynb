# %% [markdown]
# <a href="https://colab.research.google.com/github/thesuperfly21-beep/archer-t2u-plus-linux/blob/main/Copy_of_fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/AI_Models/Lora_Drive')

# %%
# !pip install "numpy<2.0" "cupy-cuda12x<14.0" --force-reinstall
# Out:
# ...
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.9/112.9 MB 25.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 kB 7.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: cupy-cuda12x
#     Found existing installation: cupy-cuda12x 14.0.1
#     Uninstalling cupy-cuda12x-14.0.1:
#       Successfully uninstalled cupy-cuda12x-14.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3648/3793612377.py in <cell line: 0>()
# ----> 1 get_ipython().system('pip install pygit2==1.15.1')
#       2 get_ipython().run_line_magic('cd', '/content')
#       3 get_ipython().system('git clone https://github.com/lllyasviel/Fooocus.git')
#       4 get_ipython().run_line_magic('cd', '/content/Fooocus')
#       5 get_ipython().system('python entry_with_update.py --share --always-high-vram')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97
#      98     if pip_warn:
# ---> 99       _pip.print_previous_import_warning(output)
#     100
#     101   def _send_error(self, exc_content):
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_pip.py in print_previous_import_warning(output)
#      54 def print_previous_import_warning(output):
# ...

# %%
# !wget -O /content/Fooocus/models/loras/Cumshot.safetensors "https://civitai.red/models/2231442/nsfw-pov-facial-zit"
# Out:
# --2026-04-18 18:49:18--  https://civitai.red/models/2231442/nsfw-pov-facial-zit
# Resolving civitai.red (civitai.red)... 104.20.31.107, 172.66.160.227, 2606:4700:10::ac42:a0e3, ...
# Connecting to civitai.red (civitai.red)|104.20.31.107|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘/content/Fooocus/models/loras/Cumshot.safetensors’
#
# /content/Fooocus/mo     [ <=>                ]  95.98K   603KB/s    in 0.2s
#
# 2026-04-18 18:49:19 (603 KB/s) - ‘/content/Fooocus/models/loras/Cumshot.safetensors’ saved [98288]

# %%
# !wget -O /content/Fooocus/models/loras/BlowjobPOV.safetensors https://civitai.red/api/download/models/2474268?type=Model&format=SafeTensor
# Out:
# --2026-04-18 18:49:20--  https://civitai.red/api/download/models/2474268?type=Model
# Resolving civitai.red (civitai.red)... 104.20.31.107, 172.66.160.227, 2606:4700:10::ac42:a0e3, ...
# Connecting to civitai.red (civitai.red)|104.20.31.107|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://b2.civitai.com/file/civitai-modelfiles/model/9572350/bjz.Qq74.safetensors?Authorization=3_20260418184920_c293e5d3aeeda1a08030b303_17b43780291c71a01e66458428251188aa045354_004_20260418194920_0034_dnld&b2ContentDisposition=attachment%3B+filename%3D%22bjz.safetensors%22 [following]
# --2026-04-18 18:49:20--  https://b2.civitai.com/file/civitai-modelfiles/model/9572350/bjz.Qq74.safetensors?Authorization=3_20260418184920_c293e5d3aeeda1a08030b303_17b43780291c71a01e66458428251188aa045354_004_20260418194920_0034_dnld&b2ContentDisposition=attachment%3B+filename%3D%22bjz.safetensors%22
# ...

# %%
# !wget -O /content/Fooocus/models/loras/MissionaryPOV.safetensors "https://civitai.red/api/download/models/140555?type=Model&format=SafeTensor"
# Out:
# --2026-04-18 18:27:23--  https://civitai.red/api/download/models/140555?type=Model&format=SafeTensor
# Resolving civitai.red (civitai.red)... 104.20.31.107, 172.66.160.227, 2606:4700:10::ac42:a0e3, ...
# Connecting to civitai.red (civitai.red)|104.20.31.107|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://b2.civitai.com/file/civitai-modelfiles/1781941/model/pm1s.TtgY.safetensors?Authorization=3_20260418182723_1595d3766fdad6fe9d5afded_192e1c06745abcf5d0c4c4a3934890efe9d22930_004_20260418192723_0035_dnld&b2ContentDisposition=attachment%3B+filename%3D%22pm1s.safetensors%22 [following]
# --2026-04-18 18:27:23--  https://b2.civitai.com/file/civitai-modelfiles/1781941/model/pm1s.TtgY.safetensors?Authorization=3_20260418182723_1595d3766fdad6fe9d5afded_192e1c06745abcf5d0c4c4a3934890efe9d22930_004_20260418192723_0035_dnld&b2ContentDisposition=attachment%3B+filename%3D%22pm1s.safetensors%22
# ...

# %%
# !wget -O /content/Fooocus/models/loras/RearPussy.safetensors "https://civitai.red/api/download/models/232190?type=Model&format=SafeTensor"
# Out:
# --2026-04-18 18:27:31--  https://civitai.red/api/download/models/232190?type=Model&format=SafeTensor
# Resolving civitai.red (civitai.red)... 104.20.31.107, 172.66.160.227, 2606:4700:10::ac42:a0e3, ...
# Connecting to civitai.red (civitai.red)|104.20.31.107|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://b2.civitai.com/file/civitai-modelfiles/model/234025/rearpussyXl10.Hrzh.safetensors?Authorization=3_20260418182731_e6a60ceff01adffc6bb1a862_ceae14d4511d0106d0538a31ab4e4b89620dce99_004_20260418192731_0043_dnld&b2ContentDisposition=attachment%3B+filename%3D%22rearpussy-xl-1.0.safetensors%22 [following]
# --2026-04-18 18:27:32--  https://b2.civitai.com/file/civitai-modelfiles/model/234025/rearpussyXl10.Hrzh.safetensors?Authorization=3_20260418182731_e6a60ceff01adffc6bb1a862_ceae14d4511d0106d0538a31ab4e4b89620dce99_004_20260418192731_0043_dnld&b2ContentDisposition=attachment%3B+filename%3D%22rearpussy-xl-1.0.safetensors%22
# ...

# %%
# !wget -O /content/Fooocus/models/loras/nudifyxl.safetensors "https://civitai.red/api/download/models/177674?type=Model&format=SafeTensor"
# Out:
# --2026-04-18 18:28:40--  https://civitai.red/api/download/models/177674?type=Model&format=SafeTensor
# Resolving civitai.red (civitai.red)... 172.66.160.227, 104.20.31.107, 2606:4700:10::ac42:a0e3, ...
# Connecting to civitai.red (civitai.red)|172.66.160.227|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://b2.civitai.com/file/civitai-modelfiles/model/156479/nudifyXlLite.cmt9.safetensors?Authorization=3_20260418182841_370b0f0d45632e00ce4ceb9b_c99b2bf518b7dd69088a27095a3307b490e3b4ca_004_20260418192841_0042_dnld&b2ContentDisposition=attachment%3B+filename%3D%22nudify_xl_lite.safetensors%22 [following]
# --2026-04-18 18:28:41--  https://b2.civitai.com/file/civitai-modelfiles/model/156479/nudifyXlLite.cmt9.safetensors?Authorization=3_20260418182841_370b0f0d45632e00ce4ceb9b_c99b2bf518b7dd69088a27095a3307b490e3b4ca_004_20260418192841_0042_dnld&b2ContentDisposition=attachment%3B+filename%3D%22nudify_xl_lite.safetensors%22
# ...

# %%
# !wget -O /content/Fooocus/models/loras/nudexl.safetensors "https://civitai.red/api/download/models/243570?type=Model&format=SafeTensor"
# Out:
# --2026-04-18 18:27:39--  https://civitai.red/api/download/models/243570?type=Model&format=SafeTensor
# Resolving civitai.red (civitai.red)... 104.20.31.107, 172.66.160.227, 2606:4700:10::ac42:a0e3, ...
# Connecting to civitai.red (civitai.red)|104.20.31.107|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://b2.civitai.com/file/civitai-modelfiles/model/14770/nudexl.iqUR.safetensors?Authorization=3_20260418182740_5ed13c024ad2d172f46b32e2_469a79b85261297cb3758d39845e6c2bf96e161c_004_20260418192740_0035_dnld&b2ContentDisposition=attachment%3B+filename%3D%22NudeXL.safetensors%22 [following]
# --2026-04-18 18:27:40--  https://b2.civitai.com/file/civitai-modelfiles/model/14770/nudexl.iqUR.safetensors?Authorization=3_20260418182740_5ed13c024ad2d172f46b32e2_469a79b85261297cb3758d39845e6c2bf96e161c_004_20260418192740_0035_dnld&b2ContentDisposition=attachment%3B+filename%3D%22NudeXL.safetensors%22
# ...

# %%
# !wget -O /content/Fooocus/models/loras/NSFWAIO.safetensors "https://civitai.red/api/download/models/160240?type=Model&format=SafeTensor"
# Out:
# --2026-04-18 18:27:53--  https://civitai.red/api/download/models/160240?type=Model&format=SafeTensor
# Resolving civitai.red (civitai.red)... 172.66.160.227, 104.20.31.107, 2606:4700:10::ac42:a0e3, ...
# Connecting to civitai.red (civitai.red)|172.66.160.227|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/116575/nsfwpovallinonelorasd.ql6p.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22NsfwPovAllInOneLoraSdxl-000009.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20260418/us-east-1/s3/aws4_request&X-Amz-Date=20260418T182753Z&X-Amz-SignedHeaders=host&X-Amz-Signature=362210810cb80bfec2665f2c3d2fcd69bb5de24e2ae89d763723ac5b7e116e3c [following]
# ...
