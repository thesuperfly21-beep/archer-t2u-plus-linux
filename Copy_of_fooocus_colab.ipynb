# %% [markdown]
# <a href="https://colab.research.google.com/github/thesuperfly21-beep/archer-t2u-plus-linux/blob/main/Copy_of_fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install "numpy<2.0" "cupy-cuda12x<14.0" --force-reinstall
# Out:
# Collecting numpy<2.0
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting cupy-cuda12x<14.0
#   Downloading cupy_cuda12x-13.6.0-cp312-cp312-manylinux2014_x86_64.whl.metadata (2.4 kB)
# Collecting fastrlock>=0.5 (from cupy-cuda12x<14.0)
#   Downloading fastrlock-0.8.3-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_28_x86_64.whl.metadata (7.7 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# Downloading cupy_cuda12x-13.6.0-cp312-cp312-manylinux2014_x86_64.whl (112.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.9/112.9 MB 26.1 MB/s eta 0:00:00
# Downloading fastrlock-0.8.3-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_28_x86_64.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 kB 7.6 MB/s eta 0:00:00
# Installing collected packages: fastrlock, numpy, cupy-cuda12x
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: cupy-cuda12x
#     Found existing installation: cupy-cuda12x 14.0.1
#     Uninstalling cupy-cuda12x-14.0.1:
#       Successfully uninstalled cupy-cuda12x-14.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# db-dtypes 1.5.1 requires packaging>=24.2.0, but you have packaging 24.1 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# access 1.1.10.post3 requires scipy>=1.14.1, but you have scipy 1.14.0 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires tqdm>=4.67, but you have tqdm 4.66.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# yfinance 0.2.66 requires websockets>=13.0, but you have websockets 11.0.3 which is incompatible.
# Successfully installed cupy-cuda12x-13.6.0 fastrlock-0.8.3 numpy-1.26.4

# %%
# !wget -O /content/Fooocus/models/loras/MissionaryPOV.safetensors "https://civitai.red/api/download/models/140555?type=Model&format=SafeTensor"
# Out:
# --2026-04-17 06:30:58--  https://civitai.red/api/download/models/140555?type=Model&format=SafeTensor
# Resolving civitai.red (civitai.red)... 172.66.160.227, 104.20.31.107, 2606:4700:10::6814:1f6b, ...
# Connecting to civitai.red (civitai.red)|172.66.160.227|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: //civitai.com/api/download/models/140555?type=Model&format=SafeTensor [following]
# --2026-04-17 06:30:58--  https://civitai.com/api/download/models/140555?type=Model&format=SafeTensor
# Resolving civitai.com (civitai.com)... 104.20.38.219, 172.66.152.186, 2606:4700:10::6814:26db, ...
# Connecting to civitai.com (civitai.com)|104.20.38.219|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://b2.civitai.com/file/civitai-modelfiles/1781941/model/pm1s.TtgY.safetensors?Authorization=3_20260417063059_2cdc70408cb4d3cc060e52ac_33c342847f384fbaea5a5cfa4667d94b0e9c3262_004_20260417073059_0035_dnld&b2ContentDisposition=attachment%3B+filename%3D%22pm1s.safetensors%22 [following]
# --2026-04-17 06:30:59--  https://b2.civitai.com/file/civitai-modelfiles/1781941/model/pm1s.TtgY.safetensors?Authorization=3_20260417063059_2cdc70408cb4d3cc060e52ac_33c342847f384fbaea5a5cfa4667d94b0e9c3262_004_20260417073059_0035_dnld&b2ContentDisposition=attachment%3B+filename%3D%22pm1s.safetensors%22
# Resolving b2.civitai.com (b2.civitai.com)... 104.20.38.219, 172.66.152.186, 2606:4700:10::ac42:98ba, ...
# Connecting to b2.civitai.com (b2.civitai.com)|104.20.38.219|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 456487716 (435M) [application/octet-stream]
# Saving to: ‘/content/Fooocus/models/loras/MissionaryPOV.safetensors’
#
# /content/Fooocus/mo 100%[===================>] 435.34M  69.9MB/s    in 9.5s
#
# 2026-04-17 06:31:09 (45.8 MB/s) - ‘/content/Fooocus/models/loras/MissionaryPOV.safetensors’ saved [456487716/456487716]

# %%
# !wget -O /content/Fooocus/models/loras/RearPussy.safetensors "https://civitai.red/api/download/models/232190?type=Model&format=SafeTensor"
# Out:
# --2026-04-17 06:31:09--  https://civitai.red/api/download/models/232190?type=Model&format=SafeTensor
# Resolving civitai.red (civitai.red)... 172.66.160.227, 104.20.31.107, 2606:4700:10::6814:1f6b, ...
# Connecting to civitai.red (civitai.red)|172.66.160.227|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: //civitai.com/api/download/models/232190?type=Model&format=SafeTensor [following]
# --2026-04-17 06:31:09--  https://civitai.com/api/download/models/232190?type=Model&format=SafeTensor
# Resolving civitai.com (civitai.com)... 104.20.38.219, 172.66.152.186, 2606:4700:10::6814:26db, ...
# Connecting to civitai.com (civitai.com)|104.20.38.219|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://b2.civitai.com/file/civitai-modelfiles/model/234025/rearpussyXl10.Hrzh.safetensors?Authorization=3_20260417063109_5423285a44c61a14701cff97_d290dcc05ee2943e2b08310669819067f35482be_004_20260417073109_0043_dnld&b2ContentDisposition=attachment%3B+filename%3D%22rearpussy-xl-1.0.safetensors%22 [following]
# --2026-04-17 06:31:09--  https://b2.civitai.com/file/civitai-modelfiles/model/234025/rearpussyXl10.Hrzh.safetensors?Authorization=3_20260417063109_5423285a44c61a14701cff97_d290dcc05ee2943e2b08310669819067f35482be_004_20260417073109_0043_dnld&b2ContentDisposition=attachment%3B+filename%3D%22rearpussy-xl-1.0.safetensors%22
# Resolving b2.civitai.com (b2.civitai.com)... 104.20.38.219, 172.66.152.186, 2606:4700:10::ac42:98ba, ...
# Connecting to b2.civitai.com (b2.civitai.com)|104.20.38.219|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 681236884 (650M) [application/octet-stream]
# Saving to: ‘/content/Fooocus/models/loras/RearPussy.safetensors’
#
# /content/Fooocus/mo 100%[===================>] 649.68M   104MB/s    in 7.5s
#
# 2026-04-17 06:31:17 (86.1 MB/s) - ‘/content/Fooocus/models/loras/RearPussy.safetensors’ saved [681236884/681236884]

# %%
# !wget -O /content/Fooocus/models/loras/nudifyxl.safetensors "https://civitai.red/api/download/models/177674?type=Model&format=SafeTensor"
# Out:
# --2026-04-17 06:31:17--  https://civitai.red/api/download/models/177674?type=Model&format=SafeTensor
# Resolving civitai.red (civitai.red)... 172.66.160.227, 104.20.31.107, 2606:4700:10::6814:1f6b, ...
# Connecting to civitai.red (civitai.red)|172.66.160.227|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: //civitai.com/api/download/models/177674?type=Model&format=SafeTensor [following]
# --2026-04-17 06:31:18--  https://civitai.com/api/download/models/177674?type=Model&format=SafeTensor
# Resolving civitai.com (civitai.com)... 104.20.38.219, 172.66.152.186, 2606:4700:10::6814:26db, ...
# Connecting to civitai.com (civitai.com)|104.20.38.219|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://b2.civitai.com/file/civitai-modelfiles/model/156479/nudifyXlLite.cmt9.safetensors?Authorization=3_20260417063118_69cbda4f744104a8ad3bf3a4_c04a56fb4c42d4d5ff9fbfcd60ab9d59aa92211d_004_20260417073118_0042_dnld&b2ContentDisposition=attachment%3B+filename%3D%22nudify_xl_lite.safetensors%22 [following]
# --2026-04-17 06:31:18--  https://b2.civitai.com/file/civitai-modelfiles/model/156479/nudifyXlLite.cmt9.safetensors?Authorization=3_20260417063118_69cbda4f744104a8ad3bf3a4_c04a56fb4c42d4d5ff9fbfcd60ab9d59aa92211d_004_20260417073118_0042_dnld&b2ContentDisposition=attachment%3B+filename%3D%22nudify_xl_lite.safetensors%22
# Resolving b2.civitai.com (b2.civitai.com)... 104.20.38.219, 172.66.152.186, 2606:4700:10::ac42:98ba, ...
# Connecting to b2.civitai.com (b2.civitai.com)|104.20.38.219|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 456489756 (435M) [application/octet-stream]
# Saving to: ‘/content/Fooocus/models/loras/nudifyxl.safetensors’
#
# /content/Fooocus/mo 100%[===================>] 435.34M  64.9MB/s    in 7.6s
#
# 2026-04-17 06:31:26 (57.2 MB/s) - ‘/content/Fooocus/models/loras/nudifyxl.safetensors’ saved [456489756/456489756]

# %%
# !wget -O /content/Fooocus/models/loras/nudexl.safetensors "https://civitai.red/api/download/models/243570?type=Model&format=SafeTensor"
# Out:
# /content/Fooocus/models/loras/nudexl.safetensors: No such file or directory

# %%
# !wget -O /content/Fooocus/models/loras/NSFWAIO.safetensors "https://civitai.red/api/download/models/160240?type=Model&format=SafeTensor"
# Out:
# --2026-04-17 06:31:27--  https://civitai.red/api/download/models/160240?type=Model&format=SafeTensor
# Resolving civitai.red (civitai.red)... 172.66.160.227, 104.20.31.107, 2606:4700:10::6814:1f6b, ...
# Connecting to civitai.red (civitai.red)|172.66.160.227|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: //civitai.com/api/download/models/160240?type=Model&format=SafeTensor [following]
# --2026-04-17 06:31:27--  https://civitai.com/api/download/models/160240?type=Model&format=SafeTensor
# Resolving civitai.com (civitai.com)... 104.20.38.219, 172.66.152.186, 2606:4700:10::6814:26db, ...
# Connecting to civitai.com (civitai.com)|104.20.38.219|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/116575/nsfwpovallinonelorasd.ql6p.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22NsfwPovAllInOneLoraSdxl-000009.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20260417/us-east-1/s3/aws4_request&X-Amz-Date=20260417T063127Z&X-Amz-SignedHeaders=host&X-Amz-Signature=8ecc58560070a295ad9278b09c0c337f867f9043b9e061395b35fff3f307237f [following]
# --2026-04-17 06:31:27--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/116575/nsfwpovallinonelorasd.ql6p.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22NsfwPovAllInOneLoraSdxl-000009.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20260417/us-east-1/s3/aws4_request&X-Amz-Date=20260417T063127Z&X-Amz-SignedHeaders=host&X-Amz-Signature=8ecc58560070a295ad9278b09c0c337f867f9043b9e061395b35fff3f307237f
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 172.64.66.1, 2606:4700:2ff9::1
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|172.64.66.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1824882988 (1.7G) [application/octet-stream]
# Saving to: ‘/content/Fooocus/models/loras/NSFWAIO.safetensors’
#
# /content/Fooocus/mo 100%[===================>]   1.70G  77.5MB/s    in 19s
#
# 2026-04-17 06:31:46 (91.1 MB/s) - ‘/content/Fooocus/models/loras/NSFWAIO.safetensors’ saved [1824882988/1824882988]

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# Requirement already satisfied: pygit2==1.15.1 in /usr/local/lib/python3.12/dist-packages (1.15.1)
# Requirement already satisfied: cffi>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from pygit2==1.15.1) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.16.0->pygit2==1.15.1) (3.0)
# /content
# fatal: destination path 'Fooocus' already exists and is not an empty directory.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Fooocus version: 2.5.5
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Total VRAM 97250 MB, total RAM 181130 MB
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 NVIDIA RTX PRO 6000 Blackwell Server Edition : native
# VAE dtype: torch.bfloat16
# Using pytorch cross attention
# /content/Fooocus/ldm_patched/unipc/uni_pc.py:56: SyntaxWarning: invalid escape sequence '\h'
#   The `alphas_cumprod` is the \hat{alpha_n} arrays in the notations of DDPM. Specifically, DDPMs assume that
# Refiner unloaded.
# Running on local URL:  http://127.0.0.1:7865
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# model_type EPS
# UNet ADM Dimension 2816
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# Running on public URL: https://869926eaa3a5a6f1e5.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# extra {'cond_stage_model.clip_l.logit_scale', 'cond_stage_model.clip_l.text_projection'}
# left over keys: dict_keys(['cond_stage_model.clip_l.transformer.text_model.embeddings.position_ids'])
# loaded straight to GPU
# Requested to load SDXL
# Loading 1 new model
# Base model loaded: /content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors
# VAE loaded: None
# Request to load LoRAs [('sd_xl_offset_example-lora_1.0.safetensors', 0.1)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 788 keys at weight 0.1.
# Fooocus V2 Expansion: Vocab with 642 words.
# Fooocus Expansion engine loaded for cuda:0, use_fp16 = True.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# 2026-04-17 06:32:04.996166: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-17 06:32:05.004019: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776407525.013985    2164 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776407525.016783    2164 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776407525.024032    2164 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776407525.024048    2164 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776407525.024050    2164 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776407525.024051    2164 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-17 06:32:05.026183: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Started worker with PID 1972
# App started successful. Use the app with http://127.0.0.1:7865/ or 127.0.0.1:7865 or https://869926eaa3a5a6f1e5.gradio.live
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 7273745178559751932
# [Parameters] CFG = 4
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Request to load LoRAs [('MissionaryPOV.safetensors', 0.62)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/MissionaryPOV.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 722 keys at weight 0.62.
# Loaded LoRA [/content/Fooocus/models/loras/MissionaryPOV.safetensors] for CLIP [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 264 keys at weight 0.62.
# Requested to load SDXLClipModel
# Loading 1 new model
# unload clone 1
# [Fooocus Model Management] Moving model(s) has taken 0.48 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Fooocus] Encoding positive #5 ...
# [Fooocus] Encoding positive #6 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Encoding negative #3 ...
# [Fooocus] Encoding negative #4 ...
# [Fooocus] Encoding negative #5 ...
# [Fooocus] Encoding negative #6 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 1.01 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/6 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.21 seconds
#  85% 51/60 [00:04<00:00, 10.28it/s]
# User stopped
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 5.33 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 6.35 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.16 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 9212828822676684433
# [Parameters] CFG = 4
# [Fooocus] Downloading upscale models ...
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_upscaler_s409985e5.bin" to /content/Fooocus/models/upscale_models/fooocus_upscaler_s409985e5.bin
#
# 100% 32.1M/32.1M [00:00<00:00, 152MB/s]
# [Fooocus] Downloading inpainter ...
# Downloading: "https://huggingface.co/lllyasviel/fooocus_inpaint/resolve/main/fooocus_inpaint_head.pth" to /content/Fooocus/models/inpaint/fooocus_inpaint_head.pth
#
# 100% 51.4k/51.4k [00:00<00:00, 4.16MB/s]
# Downloading: "https://huggingface.co/lllyasviel/fooocus_inpaint/resolve/main/inpaint_v26.fooocus.patch" to /content/Fooocus/models/inpaint/inpaint_v26.fooocus.patch
#
# 100% 1.23G/1.23G [00:05<00:00, 222MB/s]
# [Inpaint] Current inpaint model is /content/Fooocus/models/inpaint/inpaint_v26.fooocus.patch
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 48
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Synthetic Refiner Activated
# Synthetic Refiner Activated
# Request to load LoRAs [('MissionaryPOV.safetensors', 0.62), ('/content/Fooocus/models/inpaint/inpaint_v26.fooocus.patch', 1.0)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/MissionaryPOV.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 722 keys at weight 0.62.
# Loaded LoRA [/content/Fooocus/models/loras/MissionaryPOV.safetensors] for CLIP [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 264 keys at weight 0.62.
# Loaded LoRA [/content/Fooocus/models/inpaint/inpaint_v26.fooocus.patch] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 960 keys at weight 1.0.
# Request to load LoRAs [('MissionaryPOV.safetensors', 0.62)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/MissionaryPOV.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 722 keys at weight 0.62.
# Requested to load SDXLClipModel
# Loading 1 new model
# unload clone 1
# [Fooocus Model Management] Moving model(s) has taken 0.23 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Fooocus] Encoding positive #5 ...
# [Fooocus] Encoding positive #6 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Encoding negative #3 ...
# [Fooocus] Encoding negative #4 ...
# [Fooocus] Encoding negative #5 ...
# [Fooocus] Encoding negative #6 ...
# [Fooocus] Image processing ...
# Upscaling image with shape (841, 768, 3) ...
# [Fooocus] VAE Inpaint encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# [Fooocus] VAE encoding ...
# Final resolution is (768, 1360), latent is (960, 1024).
# [Parameters] Denoising Strength = 1
# [Parameters] Initial Latent shape: torch.Size([1, 4, 128, 120])
# Preparation time: 10.86 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/6 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.25 seconds
#  80% 48/60 [00:03<00:00, 12.89it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# [Fooocus Model Management] Moving model(s) has taken 0.10 seconds
# Refiner Swapped
# 100% 60/60 [00:05<00:00, 11.97it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus] Saving image 1/6 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-04-17/log.html
# Generating and saving time: 5.65 seconds
# [Fooocus] Preparing task 2/6 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.66 seconds
#  80% 48/60 [00:03<00:00, 12.80it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# Refiner Swapped
# 100% 60/60 [00:04<00:00, 12.12it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus] Saving image 2/6 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-04-17/log.html
# Generating and saving time: 5.97 seconds
# [Fooocus] Preparing task 3/6 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.23 seconds
#  80% 48/60 [00:03<00:00, 12.90it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# Refiner Swapped
# 100% 60/60 [00:04<00:00, 12.16it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus] Saving image 3/6 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-04-17/log.html
# Generating and saving time: 5.52 seconds
# [Fooocus] Preparing task 4/6 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.23 seconds
#  80% 48/60 [00:03<00:00, 12.95it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# Refiner Swapped
#  82% 49/60 [00:03<00:00, 12.29it/s]
# User stopped
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 21.36 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 32.23 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.16 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 6656953353815164052
# [Parameters] CFG = 4
# [Fooocus] Downloading upscale models ...
# [Fooocus] Downloading inpainter ...
# [Inpaint] Current inpaint model is /content/Fooocus/models/inpaint/inpaint_v26.fooocus.patch
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 48
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Synthetic Refiner Activated
# Synthetic Refiner Activated
# Request to load LoRAs [('MissionaryPOV.safetensors', 0.62)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/MissionaryPOV.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 722 keys at weight 0.62.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Fooocus] Encoding positive #5 ...
# [Fooocus] Encoding positive #6 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Encoding negative #3 ...
# [Fooocus] Encoding negative #4 ...
# [Fooocus] Encoding negative #5 ...
# [Fooocus] Encoding negative #6 ...
# [Fooocus] Image processing ...
# Upscaling image with shape (841, 768, 3) ...
# [Fooocus] VAE Inpaint encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# [Fooocus] VAE encoding ...
# Final resolution is (768, 1360), latent is (960, 1024).
# [Parameters] Denoising Strength = 1
# [Parameters] Initial Latent shape: torch.Size([1, 4, 128, 120])
# Preparation time: 2.52 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/6 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.22 seconds
#  80% 48/60 [00:03<00:00, 12.87it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# [Fooocus Model Management] Moving model(s) has taken 0.10 seconds
# Refiner Swapped
# 100% 60/60 [00:04<00:00, 12.15it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus] Saving image 1/6 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-04-17/log.html
# Generating and saving time: 5.52 seconds
# [Fooocus] Preparing task 2/6 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.23 seconds
#  80% 48/60 [00:03<00:00, 12.87it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# Refiner Swapped
# 100% 60/60 [00:04<00:00, 12.12it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus] Saving image 2/6 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-04-17/log.html
# Generating and saving time: 5.54 seconds
# [Fooocus] Preparing task 3/6 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.23 seconds
#  80% 48/60 [00:03<00:00, 12.88it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# Refiner Swapped
# 100% 60/60 [00:04<00:00, 12.12it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus] Saving image 3/6 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-04-17/log.html
# Generating and saving time: 5.54 seconds
# [Fooocus] Preparing task 4/6 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.23 seconds
#   5% 3/60 [00:00<00:05,  9.75it/s]
# User stopped
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 17.14 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 19.69 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.16 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 7386084286794052668
# [Parameters] CFG = 4
# [Fooocus] Downloading upscale models ...
# [Fooocus] Downloading inpainter ...
# [Inpaint] Current inpaint model is /content/Fooocus/models/inpaint/inpaint_v26.fooocus.patch
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 48
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Synthetic Refiner Activated
# Synthetic Refiner Activated
# Request to load LoRAs [('MissionaryPOV.safetensors', 0.62)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/MissionaryPOV.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 722 keys at weight 0.62.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Fooocus] Encoding positive #5 ...
# [Fooocus] Encoding positive #6 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Encoding negative #3 ...
# [Fooocus] Encoding negative #4 ...
# [Fooocus] Encoding negative #5 ...
# [Fooocus] Encoding negative #6 ...
# [Fooocus] Image processing ...
# Upscaling image with shape (841, 768, 3) ...
# [Fooocus] VAE Inpaint encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# [Fooocus] VAE encoding ...
# Final resolution is (768, 1360), latent is (960, 1024).
# [Parameters] Denoising Strength = 1
# [Parameters] Initial Latent shape: torch.Size([1, 4, 128, 120])
# Preparation time: 2.51 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/6 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.22 seconds
#  80% 48/60 [00:03<00:00, 12.90it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# [Fooocus Model Management] Moving model(s) has taken 0.10 seconds
# Refiner Swapped
# 100% 60/60 [00:04<00:00, 12.12it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus] Saving image 1/6 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-04-17/log.html
# Generating and saving time: 5.53 seconds
# [Fooocus] Preparing task 2/6 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.23 seconds
#  80% 48/60 [00:03<00:00, 12.88it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# Refiner Swapped
# 100% 60/60 [00:04<00:00, 12.13it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus] Saving image 2/6 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-04-17/log.html
# Generating and saving time: 5.53 seconds
# [Fooocus] Preparing task 3/6 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.23 seconds
#  80% 48/60 [00:03<00:00, 12.91it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# Refiner Swapped
# 100% 60/60 [00:04<00:00, 12.17it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus] Saving image 3/6 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-04-17/log.html
# Generating and saving time: 5.52 seconds
# [Fooocus] Preparing task 4/6 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.23 seconds
#  80% 48/60 [00:03<00:00, 12.94it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# Refiner Swapped
# 100% 60/60 [00:04<00:00, 12.17it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus] Saving image 4/6 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-04-17/log.html
# Generating and saving time: 5.52 seconds
# [Fooocus] Preparing task 5/6 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.23 seconds
#  80% 48/60 [00:03<00:00, 12.90it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# Refiner Swapped
# 100% 60/60 [00:04<00:00, 12.17it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus] Saving image 5/6 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-04-17/log.html
# Generating and saving time: 5.52 seconds
# [Fooocus] Preparing task 6/6 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.23 seconds
#  73% 44/60 [00:03<00:01, 12.60it/s]
# User stopped
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 31.35 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 33.89 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.17 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 5247358025844941357
# [Parameters] CFG = 4
# [Fooocus] Downloading upscale models ...
# [Fooocus] Downloading inpainter ...
# [Inpaint] Current inpaint model is /content/Fooocus/models/inpaint/inpaint_v26.fooocus.patch
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 48
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Synthetic Refiner Activated
# Synthetic Refiner Activated
# Request to load LoRAs [('MissionaryPOV.safetensors', 0.62)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/MissionaryPOV.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 722 keys at weight 0.62.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Fooocus] Encoding positive #5 ...
# [Fooocus] Encoding positive #6 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Encoding negative #3 ...
# [Fooocus] Encoding negative #4 ...
# [Fooocus] Encoding negative #5 ...
# [Fooocus] Encoding negative #6 ...
# [Fooocus] Image processing ...
# Upscaling image with shape (644, 768, 3) ...
# [Fooocus] VAE Inpaint encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# [Fooocus] VAE encoding ...
# Final resolution is (768, 1360), latent is (1088, 960).
# [Parameters] Denoising Strength = 1
# [Parameters] Initial Latent shape: Image Space (960, 1088)
# Preparation time: 2.15 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/6 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.22 seconds
#  80% 48/60 [00:03<00:00, 12.64it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# [Fooocus Model Management] Moving model(s) has taken 0.10 seconds
# Refiner Swapped
# 100% 60/60 [00:05<00:00, 11.84it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus] Saving image 1/6 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-04-17/log.html
# Generating and saving time: 5.66 seconds
# [Fooocus] Preparing task 2/6 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.23 seconds
#  80% 48/60 [00:03<00:00, 12.58it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# Refiner Swapped
#  90% 54/60 [00:04<00:00, 11.84it/s]
# User stopped
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 10.46 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 12.63 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.16 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 5388964753542820817
# [Parameters] CFG = 4
# [Fooocus] Downloading upscale models ...
# [Fooocus] Downloading inpainter ...
# [Inpaint] Current inpaint model is /content/Fooocus/models/inpaint/inpaint_v26.fooocus.patch
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 48
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Synthetic Refiner Activated
# Synthetic Refiner Activated
# Request to load LoRAs [('MissionaryPOV.safetensors', 0.62)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/MissionaryPOV.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 722 keys at weight 0.62.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Fooocus] Encoding positive #5 ...
# [Fooocus] Encoding positive #6 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Encoding negative #3 ...
# [Fooocus] Encoding negative #4 ...
# [Fooocus] Encoding negative #5 ...
# [Fooocus] Encoding negative #6 ...
# [Fooocus] Image processing ...
# Upscaling image with shape (644, 768, 3) ...
# [Fooocus] VAE Inpaint encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# [Fooocus] VAE encoding ...
# Final resolution is (768, 1360), latent is (1088, 960).
# [Parameters] Denoising Strength = 1
# [Parameters] Initial Latent shape: Image Space (960, 1088)
# Preparation time: 2.14 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/6 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.22 seconds
#  80% 48/60 [00:03<00:00, 12.62it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# [Fooocus Model Management] Moving model(s) has taken 0.10 seconds
# Refiner Swapped
# 100% 60/60 [00:05<00:00, 11.91it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus] Saving image 1/6 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-04-17/log.html
# Generating and saving time: 5.63 seconds
# [Fooocus] Preparing task 2/6 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.23 seconds
#  80% 48/60 [00:03<00:00, 12.60it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# Refiner Swapped
# 100% 60/60 [00:05<00:00, 11.94it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus] Saving image 2/6 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-04-17/log.html
# Generating and saving time: 5.63 seconds
# [Fooocus] Preparing task 3/6 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.23 seconds
#  80% 48/60 [00:03<00:00, 12.60it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# Refiner Swapped
# 100% 60/60 [00:05<00:00, 11.89it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus] Saving image 3/6 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-04-17/log.html
# Generating and saving time: 5.65 seconds
# [Fooocus] Preparing task 4/6 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.23 seconds
#  80% 48/60 [00:03<00:00, 12.55it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# Refiner Swapped
# 100% 60/60 [00:05<00:00, 11.89it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus] Saving image 4/6 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-04-17/log.html
# Generating and saving time: 5.65 seconds
# [Fooocus] Preparing task 5/6 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.23 seconds
#  80% 48/60 [00:03<00:00, 12.62it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# Refiner Swapped
# 100% 60/60 [00:05<00:00, 11.96it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus] Saving image 5/6 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-04-17/log.html
# Generating and saving time: 5.62 seconds
# [Fooocus] Preparing task 6/6 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.23 seconds
#  80% 48/60 [00:03<00:00, 12.61it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# Refiner Swapped
# 100% 60/60 [00:05<00:00, 11.93it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus] Saving image 6/6 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2026-04-17/log.html
# Generating and saving time: 5.63 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 33.81 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 35.99 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.15 seconds
# Keyboard interruption in main thread... closing server.Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 2199, in block_thread
#     time.sleep(0.1)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/Fooocus/entry_with_update.py", line 46, in <module>
#     from launch import *
#   File "/content/Fooocus/launch.py", line 152, in <module>
#     from webui import *
#   File "/content/Fooocus/webui.py", line 1120, in <module>
#     shared.gradio_root.launch(
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 2115, in launch
#     self.block_thread()
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 2201, in block_thread
#     print("Keyboard interruption in main thread... closing server.")
#   File "/usr/local/lib/python3.12/dist-packages/wandb/sdk/lib/console_capture.py", line 186, in write_with_callbacks
#     with contextlib.ExitStack() as stack:
#          ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/contextlib.py", line 564, in __enter__
#     def __enter__(self):
#
# KeyboardInterrupt
# Killing tunnel 127.0.0.1:7865 <> https://869926eaa3a5a6f1e5.gradio.live
